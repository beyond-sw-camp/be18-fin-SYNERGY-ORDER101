# %%
# !pip install kaggle pandas numpy
# Out:
# Requirement already satisfied: kaggle in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (1.8.2)
# Requirement already satisfied: pandas in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (2.3.1)
# Requirement already satisfied: numpy in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (2.3.2)
# Requirement already satisfied: black>=24.10.0 in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (25.11.0)
# Requirement already satisfied: bleach in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: kagglesdk in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (0.1.13)
# Requirement already satisfied: mypy>=1.15.0 in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (1.18.2)
# Requirement already satisfied: protobuf in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (6.33.1)
# Requirement already satisfied: python-dateutil in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (2.32.4)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (80.9.0)
# Requirement already satisfied: six>=1.10 in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: tqdm in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: types-requests in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (2.32.4.20250913)
# Requirement already satisfied: types-tqdm in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (4.67.0.20250809)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (2.5.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\chosw\appdata\roaming\python\python313\site-packages (from black>=24.10.0->kaggle) (8.2.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from black>=24.10.0->kaggle) (1.1.0)
# Requirement already satisfied: packaging>=22.0 in c:\users\chosw\appdata\roaming\python\python313\site-packages (from black>=24.10.0->kaggle) (25.0)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from black>=24.10.0->kaggle) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in c:\users\chosw\appdata\roaming\python\python313\site-packages (from black>=24.10.0->kaggle) (4.3.8)
# Requirement already satisfied: pytokens>=0.3.0 in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from black>=24.10.0->kaggle) (0.3.0)
# Requirement already satisfied: colorama in c:\users\chosw\appdata\roaming\python\python313\site-packages (from click>=8.0.0->black>=24.10.0->kaggle) (0.4.6)
# Requirement already satisfied: typing_extensions>=4.6.0 in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from mypy>=1.15.0->kaggle) (4.14.1)
# Requirement already satisfied: webencodings in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from requests->kaggle) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from requests->kaggle) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chosw\appdata\local\programs\python\python313\lib\site-packages (from requests->kaggle) (2025.8.3)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import json
import getpass
from pathlib import Path

kaggle_dir = Path.home() / ".kaggle"
kaggle_dir.mkdir(exist_ok=True)

kaggle_json = kaggle_dir / "kaggle.json"

if not kaggle_json.exists():
    print("Kaggle API Key")
    KAGGLE_USERNAME = input("KAGGLE_USERNAME: ")
    KAGGLE_KEY = getpass.getpass("KAGGLE_KEY: ")
    
    kaggle_json.write_text(json.dumps({
        "username": KAGGLE_USERNAME,
        "key": KAGGLE_KEY
    }))

# 권한 설정
os.chmod(kaggle_json, 0o600)

# %%
# raw 폴더 생성
RAW_DIR = Path("raw")
RAW_DIR.mkdir(exist_ok=True)

# Kaggle 다운로드
# !kaggle competitions download -c demand-forecasting-kernels-only -p raw
# Out:
# demand-forecasting-kernels-only.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile

zip_path = RAW_DIR / "demand-forecasting-kernels-only.zip"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(RAW_DIR)

# 압축 해제 결과 확인
os.listdir(RAW_DIR)
# Out:
# ['demand-forecasting-kernels-only.zip',
#  'sample_submission.csv',
#  'test.csv',
#  'train.csv']

# %%
import pandas as pd

df = pd.read_csv("raw/train.csv")
df["date"] = pd.to_datetime(df["date"])

# %%
weekly = (
    df.groupby(["store", "item", pd.Grouper(key="date", freq="W-MON")])["sales"]
      .sum()
      .reset_index()
      .rename(columns={
          "store": "store_id",
          "item": "product_id",
          "date": "target_date",
          "sales": "actual_order_qty"
      })
)

product_map = {
    1: "TV", 2: "냉장고", 3: "세탁기", 4: "에어컨", 5: "전자레인지",
    6: "청소기", 7: "공기청정기", 8: "커피머신", 9: "오븐", 10: "식기세척기"
}
weekly["product_name"] = weekly["product_id"].map(product_map).fillna("기타가전")
weekly["warehouse_id"] = (weekly["store_id"] % 3) + 1

weekly.to_csv("weekly_sales.csv", index=False)
weekly.sample(300, random_state=42).to_csv("weekly_sales_sample.csv", index=False)

len(weekly), weekly.head()
# Out:
# (130500,
#     store_id  product_id target_date  actual_order_qty product_name  \
#  0         1           1  2013-01-07                83           TV
#  1         1           1  2013-01-14                68           TV
#  2         1           1  2013-01-21                76           TV
#  3         1           1  2013-01-28                73           TV
#  4         1           1  2013-02-04                89           TV
#
#     warehouse_id
#  0             2
#  1             2
#  2             2
#  3             2
#  4             2  )
